# %%
import pandas as pd

# %%
df1 = pd.read_excel('FinancialSample.xlsx','Sheet1')

# %%
df1.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df2 = pd.read_excel('FinancialSample.xlsx','Sheet2')

# %%
df2.head(3)
# Out:
#         Date Sales Rep  Shift  Cost Price  Selling Price  Profit  Profit %  \
# 0 2022-07-01       Ben  Night     1112.94        1288.00     NaN       NaN
# 1 2022-07-01     Jacob    Day     1095.50        1250.75     NaN       NaN
# 2 2022-07-04       Ben  Night     1120.94        1295.00     NaN       NaN
#
#    Commission  Weekday
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN

# %% [markdown]
# # Filter with multiple values in single column

# %%
df1[df1['Country'].isin(['Canada','Germany'])].head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 5  Government  Germany  Carretera          None      1513.0
# 6   Midmarket  Germany    Montana          None       921.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# 1                    3          20      26420.0        0.0   26420.0
# 3                    3          15      13320.0        0.0   13320.0
# 5                    3         350     529550.0        0.0  529550.0
# 6                    5          15      13815.0        0.0   13815.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 0   16185.0   16185.0 2014-01-01             1    January  2014
# ...

# %%
#Filter data where Segment shoud be either 'Government' or 'Midmarket' and Product should be either 'Carretera' or 'Montana'

# %%
df1[df1['Segment'].isin(['Government','Midmarket']) & df1['Product'].isin(['Carretera','Montana']) & (df1['Profit']>=5000.0)].head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
# 5  Government  Germany  Carretera          None      1513.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# 1                    3          20      26420.0        0.0   26420.0
# 2                    3          15      32670.0        0.0   32670.0
# 4                    3          15      37050.0        0.0   37050.0
# 5                    3         350     529550.0        0.0  529550.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 0   16185.0   16185.0 2014-01-01             1    January  2014
# ...

# %% [markdown]
# #Joining 2 dataframes

# %%
part1 = df1[df1['Country'] == 'Canada']

# %%
part2 = df1[df1['Country'] == 'Germany']

# %%
part1.head()
# Out:
#              Segment Country    Product Discount Band  Units Sold  \
# 0         Government  Canada  Carretera          None      1618.5
# 7   Channel Partners  Canada    Montana          None      2518.0
# 11        Enterprise  Canada    Montana          None      2665.5
# 14        Enterprise  Canada    Montana          None       345.0
# 16        Government  Canada      Paseo          None       292.0
#
#     Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                     3          20      32370.0        0.0   32370.0
# 7                     5          12      30216.0        0.0   30216.0
# 11                    5         125     333187.5        0.0  333187.5
# 14                    5         125      43125.0        0.0   43125.0
# 16                   10          20       5840.0        0.0    5840.0
#
#         COGS   Profit       Date  Month Number Month Name  Year
# 0    16185.0  16185.0 2014-01-01             1    January  2014
# ...

# %%
part2.head()
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 1        Government  Germany  Carretera          None      1321.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 5        Government  Germany  Carretera          None      1513.0
# 6         Midmarket  Germany    Montana          None       921.0
# 9  Channel Partners  Germany    Montana          None      1545.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 1                    3          20      26420.0        0.0   26420.0
# 3                    3          15      13320.0        0.0   13320.0
# 5                    3         350     529550.0        0.0  529550.0
# 6                    5          15      13815.0        0.0   13815.0
# 9                    5          12      18540.0        0.0   18540.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 1   13210.0   13210.0 2014-01-01             1    January  2014
# ...

# %%
df_concat = pd.concat([part1,part2], axis = 0)

# %%
df_concat
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government   Canada  Carretera          None      1618.5
# 7    Channel Partners   Canada    Montana          None      2518.0
# 11         Enterprise   Canada    Montana          None      2665.5
# 14         Enterprise   Canada    Montana          None       345.0
# 16         Government   Canada      Paseo          None       292.0
# ..                ...      ...        ...           ...         ...
# 676        Enterprise  Germany      Paseo          High      1085.0
# 677         Midmarket  Germany      Paseo          High      1175.0
# 689         Midmarket  Germany        VTT          High       492.0
# 691         Midmarket  Germany        VTT          High      1175.0
# 693        Enterprise  Germany        VTT          High       552.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3          20      32370.0       0.00   32370.00
# ...

# %%
part3 = df1[['Segment','Country','Product']]

# %%
part4 = df1[['COGS','Profit']]

# %%
part3.head()
# Out:
#       Segment  Country    Product
# 0  Government   Canada  Carretera
# 1  Government  Germany  Carretera
# 2   Midmarket   France  Carretera
# 3   Midmarket  Germany  Carretera
# 4   Midmarket   Mexico  Carretera

# %%
part4.head()
# Out:
#       COGS   Profit
# 0  16185.0  16185.0
# 1  13210.0  13210.0
# 2  21780.0  10890.0
# 3   8880.0   4440.0
# 4  24700.0  12350.0

# %%
df_concated = pd.concat([part3,part4],axis = 1)

# %%
df_concated
# Out:
#               Segment                   Country    Product      COGS    Profit
# 0          Government                    Canada  Carretera   16185.0  16185.00
# 1          Government                   Germany  Carretera   13210.0  13210.00
# 2           Midmarket                    France  Carretera   21780.0  10890.00
# 3           Midmarket                   Germany  Carretera    8880.0   4440.00
# 4           Midmarket                    Mexico  Carretera   24700.0  12350.00
# ..                ...                       ...        ...       ...       ...
# 695    Small Business                    France   Amarilla  618750.0  12375.00
# 696    Small Business                    Mexico   Amarilla  136500.0   2730.00
# 697        Government                    Mexico    Montana    6840.0   1299.60
# 698        Government                    Canada      Paseo    3615.0    686.85
# 699  Channel Partners  United States of America        VTT    5418.0  13003.20
#
# [700 rows x 5 columns]

# %% [markdown]
# #Aggregate functions
#
# Data is grouped by Categorical column and Numerical columns are aggregated.

# %%
filtered = df_concated[['Segment','Profit']]

# %%
filtered
# Out:
#               Segment    Profit
# 0          Government  16185.00
# 1          Government  13210.00
# 2           Midmarket  10890.00
# 3           Midmarket   4440.00
# 4           Midmarket  12350.00
# ..                ...       ...
# 695    Small Business  12375.00
# 696    Small Business   2730.00
# 697        Government   1299.60
# 698        Government    686.85
# 699  Channel Partners  13003.20
#
# [700 rows x 2 columns]

# %%
filtered.groupby('Segment').agg('min')
# Out:
#                     Profit
# Segment
# Channel Partners   2423.52
# Enterprise       -40617.50
# Government          285.60
# Midmarket           806.20
# Small Business     2152.00

# %%
filtered.groupby('Segment').agg('mean')
# Out:
#                         Profit
# Segment
# Channel Partners  13168.031400
# Enterprise        -6145.456250
# Government        37960.577233
# Midmarket          6601.030750
# Small Business    41431.685000

# %%
df1 = pd.read_excel('FinancialSample.xlsx','Sheet1')
df1.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
# Get data only for countries 'Canada' , 'Germany' or 'France' where minimum 500 units should be sold.
# Perform column based slicing with 'Country' and 'Units Sold'
# Find average units sold for each country

# %%
x2 = df1[df1['Country'].isin(['Canada','Germany','France']) & (df1['Units Sold']>500)]

# %%
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 0        Government   Canada  Carretera          None      1618.5
# 1        Government  Germany  Carretera          None      1321.0
# 2         Midmarket   France  Carretera          None      2178.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 5        Government  Germany  Carretera          None      1513.0
# ..              ...      ...        ...           ...         ...
# 691       Midmarket  Germany        VTT          High      1175.0
# 692      Enterprise   Canada        VTT          High      2954.0
# 693      Enterprise  Germany        VTT          High       552.0
# 695  Small Business   France   Amarilla          High      2475.0
# 698      Government   Canada      Paseo          High       723.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3          20      32370.0       0.00   32370.00
# ...

# %%
x2 = x1[['Country','Units Sold']]

# %%
x2.head()
# Out:
#    Country  Units Sold
# 0   Canada      1618.5
# 1  Germany      1321.0
# 2   France      2178.0
# 3  Germany       888.0
# 5  Germany      1513.0

# %%
x2.groupby('Country').agg('mean')
# Out:
#           Units Sold
# Country
# Canada   1891.267442
# France   1836.821705
# Germany  1612.776860
