# %%
import pandas as pd

# %%
df = pd.read_excel('FinancialSample.xlsx','Sheet1')

# %%
df.isna().sum()
# Out:
# Segment                  0
# Country                  0
# Product                  0
# Discount Band            0
# Units Sold               0
# Manufacturing Price      0
# Sale Price               0
# Gross Sales              0
# Discounts                0
#  Sales                   0
# COGS                    28
# Profit                 137
# Date                    14
# Month Number             0
# Month Name               0
# Year                     0
# dtype: int64

# %%
df.isna().mean()
# Out:
# Segment                0.000000
# Country                0.000000
# Product                0.000000
# Discount Band          0.000000
# Units Sold             0.000000
# Manufacturing Price    0.000000
# Sale Price             0.000000
# Gross Sales            0.000000
# Discounts              0.000000
#  Sales                 0.000000
# COGS                   0.040000
# Profit                 0.195714
# Date                   0.020000
# Month Number           0.000000
# Month Name             0.000000
# Year                   0.000000
# dtype: float64

# %% [markdown]
# #Assign value to perticular cell

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#         Date  Month Number Month Name  Year India_Appended  \
# 0 2014-01-01             1    January  2014    IndiaCanada
# ...

# %% [markdown]
# #Operation between columns

# %%
df["India_Appended"] = "India" + df["Country"]

# %%
df["Concated"] = df["Country"] + "_____" + df["Product"]

# %%
df['Negative_Sales_Price'] = df['Sale Price'] * (-1)

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year India_Appended  \
# 0  16185.0 2014-01-01             1    January  2014    IndiaCanada
# ...

# %%
df["ratio"] = (df['Profit']/df[' Sales'])*100

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year India_Appended  \
# 0  16185.0 2014-01-01             1    January  2014    IndiaCanada
# ...

# %% [markdown]
# #Apply Method

# %%
def find_length(st):
  l = len(st)
  return(l)

# %%
df['Product_legth'] = df['Product'].apply(find_length)

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales  ...  \
# 0                    3          20      32370.0        0.0  32370.0  ...
# 1                    3          20      26420.0        0.0  26420.0  ...
# 2                    3          15      32670.0        0.0  32670.0  ...
# 3                    3          15      13320.0        0.0  13320.0  ...
# 4                    3          15      37050.0        0.0  37050.0  ...
#
#     Profit       Date Month Number  Month Name  Year  India_Appended  \
# 0  16185.0 2014-01-01            1     January  2014     IndiaCanada
# ...

# %%
# Filter data with Products 'Paseo' and 'VTT'
#Find total null counts for each columns. The column which have highest nulls , drop that column.
#Filter the resultant data with canada country only
# perform group by on "segment" column to find maximum sales on each segment

# %%
df1 = df[df['Product'].isin(['Paseo','VTT'])]

df1.isna().sum()

del df1['ratio'],df1['Profit']

df2 = df1[df1['Country'] == 'Canada']

df3 = df2[['Segment',' Sales']]
df3.groupby('Segment').agg('max')
