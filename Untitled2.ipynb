# %%
import pandas as pd

df=pd.read_csv("california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27       3885.0           661.0
# 1    -118.30     34.26                  43       1510.0           310.0
# 2    -117.81     33.78                  27       3589.0           507.0
# 3    -118.36     33.82                  28         67.0            15.0
# 4    -119.67     36.33                  19       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# 1         809         277         3.5990              176500
# 2        1484         495         5.7934              270500
# 3          49          11         6.1359              330000
# 4         850         237         2.9375               81700

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995        NaN     34.42                  23       1450.0           642.0
# 2996        NaN     34.06                  27       5257.0          1082.0
# 2997    -119.70     36.30                  10        956.0           201.0
# 2998    -117.12     34.10                  40         96.0            14.0
# 2999    -119.63     34.42                  42       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995        1258         607         1.1790              225000
# 2996        3496        1036         3.3906              237200
# 2997         693         220         2.2895               62000
# 2998          46          14         3.2708              162500
# 2999         753         260         8.5608              500001

# %%
df.isna().mean()
# Out:
# longitude             0.997000
# latitude              0.002333
# housing_median_age    0.000000
# total_rooms           0.004000
# total_bedrooms        0.001667
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# dtype: float64

# %%
df.isna().sum()
# Out:
# latitude               7
# housing_median_age     0
# total_rooms           12
# total_bedrooms         5
# population             0
# households             0
# median_income          0
# median_house_value     0
# dtype: int64

# %%
del df['longitude']

# %%
df=df.reset_index(drop=True)

# %%
df = df.dropna(subset = ['total_rooms'])

# %%
df=df.reset_index(drop=True)
df
# Out:
#       latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        37.37                  27       3885.0           661.0        1537
# 1        34.26                  43       1510.0           310.0         809
# 2        33.78                  27       3589.0           507.0        1484
# 3        33.82                  28         67.0            15.0          49
# 4        36.33                  19       1241.0           244.0         850
# ...        ...                 ...          ...             ...         ...
# 2983     34.42                  23       1450.0           642.0        1258
# 2984     34.06                  27       5257.0          1082.0        3496
# 2985     36.30                  10        956.0           201.0         693
# 2986     34.10                  40         96.0            14.0          46
# 2987     34.42                  42       1765.0           263.0         753
#
#       households  median_income  median_house_value
# ...

# %%
df['latitude'] = df['latitude'].fillna(df['latitude'].mean())

# %%
df=df.reset_index(drop=True)
df
# Out:
#       latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        37.37                  27       3885.0           661.0        1537
# 1        34.26                  43       1510.0           310.0         809
# 2        33.78                  27       3589.0           507.0        1484
# 3        33.82                  28         67.0            15.0          49
# 4        36.33                  19       1241.0           244.0         850
# ...        ...                 ...          ...             ...         ...
# 2983     34.42                  23       1450.0           642.0        1258
# 2984     34.06                  27       5257.0          1082.0        3496
# 2985     36.30                  10        956.0           201.0         693
# 2986     34.10                  40         96.0            14.0          46
# 2987     34.42                  42       1765.0           263.0         753
#
#       households  median_income  median_house_value
# ...

# %%
df.isna().sum()
# Out:
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        5
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())

# %%
df=df.reset_index(drop=True)
df
# Out:
#       latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0        37.37                  27       3885.0           661.0        1537
# 1        34.26                  43       1510.0           310.0         809
# 2        33.78                  27       3589.0           507.0        1484
# 3        33.82                  28         67.0            15.0          49
# 4        36.33                  19       1241.0           244.0         850
# ...        ...                 ...          ...             ...         ...
# 2983     34.42                  23       1450.0           642.0        1258
# 2984     34.06                  27       5257.0          1082.0        3496
# 2985     36.30                  10        956.0           201.0         693
# 2986     34.10                  40         96.0            14.0          46
# 2987     34.42                  42       1765.0           263.0         753
#
#       households  median_income  median_house_value
# ...

# %%
df[df['population']<df['population'].mean()]
# Out:
#        latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 1     34.260000                  43       1510.0           310.0         809
# 3     33.820000                  28         67.0            15.0          49
# 4     36.330000                  19       1241.0           244.0         850
# 5     36.510000                  37       1018.0           213.0         663
# 6     35.632603                  43       1009.0           225.0         604
# ...         ...                 ...          ...             ...         ...
# 2982  33.860000                  35        931.0           181.0         516
# 2983  34.420000                  23       1450.0           642.0        1258
# 2985  36.300000                  10        956.0           201.0         693
# 2986  34.100000                  40         96.0            14.0          46
# 2987  34.420000                  42       1765.0           263.0         753
#
# ...

# %%
new_df=df[['population','total_bedrooms']]
new_df.head()
# Out:
#    population  total_bedrooms
# 0        1537           661.0
# 1         809           310.0
# 2        1484           507.0
# 3          49            15.0
# 4         850           244.0

# %%
my_dict = df.set_index('total_bedrooms')['population'].to_dict()
my_dict
# Out:
# {661.0: 1847,
#  310.0: 746,
#  507.0: 1311,
#  15.0: 32,
#  244.0: 716,
#  213.0: 488,
#  225.0: 769,
#  471.0: 1155,
#  617.0: 1155,
#  632.0: 1686,
#  249.0: 1108,
#  166.0: 401,
#  182.0: 535,
#  694.0: 770,
#  1030.0: 2697,
#  418.0: 1344,
#  1609.0: 3751,
#  954.0: 1941,
#  220.0: 772,
#  493.0: 836,
#  705.0: 1693,
#  2971.0: 8152,
#  170.0: 903,
#  726.0: 1905,
#  451.0: 944,
#  251.0: 894,
#  203.0: 514,
#  437.0: 1754,
#  286.0: 564,
#  1874.0: 3925,
#  338.0: 733,
#  369.0: 912,
#  1698.0: 1825,
#  1887.0: 4356,
#  121.0: 426,
#  500.0: 1223,
#  380.0: 1177,
#  333.0: 1689,
#  233.0: 899,
#  528.0: 1478,
#  468.0: 1261,
#  291.0: 784,
#  600.0: 983,
#  140.0: 408,
#  317.0: 996,
#  305.0: 979,
#  299.0: 1535,
#  399.0: 928,
#  768.0: 2962,
#  1212.0: 3559,
#  319.0: 980,
#  750.0: 2767,
#  367.0: 927,
#  382.0: 774,
#  544.0: 1039,
#  442.0: 861,
#  419.0: 614,
#  631.0: 1007,
#  858.0: 1441,
#  1002.0: 3129,
#  130.0: 504,
#  384.0: 882,
#  324.0: 1076,
#  1416.0: 3927,
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
scaler1 = MinMaxScaler()
df2[["Units Sold_MinMaxScalled"]] = scaler.fit_transform(df[["Units Sold"]])
scaler2 = StandardScaler()
df2[["Units Sold_StandardScalled"]] = scaler.fit_transform(df[["Units Sold"]])
ohe = OneHotEncoder(sparse=False)

result = ohe.fit_transform(df[['Segment']])
